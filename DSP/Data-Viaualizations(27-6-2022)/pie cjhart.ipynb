# %%
#here anticlock pie chart in google defaultly clock pie chart
import matplotlib.pyplot as plt
import numpy as np 
y=np.array([35,50,15])
plt.pie(y)
plt.show()

# %%
plt.pie(y,colors=["r","b","hotpink"],labels=["DSP","CD","WT"])
plt.show()
#co=[r,b,pink],colors=co

# %%
plt.pie(y,colors=["r","b","hotpink"],labels=["DSP","CD","WT"])
plt.legend(title="Subjects")
plt.show()
#pie(V)
