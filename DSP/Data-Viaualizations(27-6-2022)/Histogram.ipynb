# %%
import matplotlib.pyplot as plt
import numpy as np
num=[2,4,2,5,2,5,7]
plt.hist(num)
plt.show()
#hist(v,bins)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.hist(num,bins=5,ec="black",color="pink")
plt.show()
