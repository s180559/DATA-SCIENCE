# %% [markdown]
# # Importing csv

# %%
import pandas as pd
df=pd.read_csv("fname.csv")
df
# Out:
#        Name   id  age
# 0      asdf  NaN    6
# 1     divya   13   18
# 2      tanu   14   18
# 3     madhu    ?   19
# 4       sai   16   19
# 5     kanna   17    7
# 6   kishore   18   23
# 7       sri   19   12
# 8      ammu  Nan   17
# 9      ammu   21   18
# 10     asdf  NaN    6
# 11    divya   13   18

# %% [markdown]
# # Conversion of csv to excel

# %%
a=pd.read_csv("fname.csv")
a.to_excel("records.xlsx")
a=pd.read_excel("records.xlsx")
a
# Out:
#     Unnamed: 0     Name   id  age
# 0            0     asdf  NaN    6
# 1            1    divya   13   18
# 2            2     tanu   14   18
# 3            3    madhu    ?   19
# 4            4      sai   16   19
# 5            5    kanna   17    7
# 6            6  kishore   18   23
# 7            7      sri   19   12
# 8            8     ammu  Nan   17
# 9            9     ammu   21   18
# 10          10     asdf  NaN    6
# 11          11    divya   13   18

# %% [markdown]
# # Creating dataframe using dictionary

# %%
di={"Name":["divya","kanna","ammu"],"R_no":[2,6,7],"perc":[4.5,5.6,7.5]}
di
# Out:
# {'Name': ['divya', 'kanna', 'ammu'],
#  'R_no': [2, 6, 7],
#  'perc': [4.5, 5.6, 7.5]}

# %%
dic=pd.DataFrame(di)
dic
# Out:
#     Name  R_no  perc
# 0  divya     2   4.5
# 1  kanna     6   5.6
# 2   ammu     7   7.5

# %% [markdown]
# # Creating datframe using tuples

# %%
l=[('divi',10,100),('sai',11,99.8),('kivya',12,100)]
list=pd.DataFrame(l)
list
# Out:
#        0   1      2
# 0   divi  10  100.0
# 1    sai  11   99.8
# 2  kivya  12  100.0

# %% [markdown]
# # Data accessing with loc

# %%
df.loc[4]
# Out:
# Name    sai
# id       16
# age      19
# Name: 4, dtype: object

# %%
df.loc[1,"Name"]
# Out:
# 'divya'

# %%
newdf=df[(df.age <20)]
print(newdf)
# Out:
#      Name   id  age
# 0    asdf  NaN    6
# 1   divya   13   18
# 2    tanu   14   18
# 3   madhu    ?   19
# 4     sai   16   19
# 5   kanna   17    7
# 7     sri   19   12
# 8    ammu  Nan   17
# 9    ammu   21   18
# 10   asdf  NaN    6
# 11  divya   13   18

# %%
df.loc[df["age"]>8]
# Out:
#        Name   id  age
# 1     divya   13   18
# 2      tanu   14   18
# 3     madhu    ?   19
# 4       sai   16   19
# 6   kishore   18   23
# 7       sri   19   12
# 8      ammu  Nan   17
# 9      ammu   21   18
# 11    divya   13   18

# %%
df.loc[df["age"]>8]
# Out:
#        Name   id  age
# 1     divya   13   18
# 2      tanu   14   18
# 3     madhu    ?   19
# 4       sai   16   19
# 6   kishore   18   23
# 7       sri   19   12
# 8      ammu  Nan   17
# 9      ammu   21   18
# 11    divya   13   18

# %%
df.loc[df["age"]>20]
# Out:
#       Name  id  age
# 6  kishore  18   23

# %%
df1=df.at[1,'Name']
df1
# Out:
# 'divya'

# %% [markdown]
# # Index slicing

# %%
df.head(5)
# Out:
#     Name   id  age
# 0   asdf  NaN    6
# 1  divya   13   18
# 2   tanu   14   18
# 3  madhu    ?   19
# 4    sai   16   19

# %%
df.tail(4)
# Out:
#      Name   id  age
# 8    ammu  Nan   17
# 9    ammu   21   18
# 10   asdf  NaN    6
# 11  divya   13   18

# %%
df.describe()
# Out:
#              age
# count  12.000000
# mean   15.083333
# std     5.806866
# min     6.000000
# 25%    10.750000
# 50%    18.000000
# 75%    18.250000
# max    23.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    12 non-null     object
#  1   id      10 non-null     object
#  2   age     12 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 416.0+ bytes

# %%
df[0:10:1]
# Out:
#       Name   id  age
# 0     asdf  NaN    6
# 1    divya   13   18
# 2     tanu   14   18
# 3    madhu    ?   19
# 4      sai   16   19
# 5    kanna   17    7
# 6  kishore   18   23
# 7      sri   19   12
# 8     ammu  Nan   17
# 9     ammu   21   18

# %% [markdown]
# # Entire column access

# %%
df['age']
# Out:
# 0      6
# 1     18
# 2     18
# 3     19
# 4     19
# 5      7
# 6     23
# 7     12
# 8     17
# 9     18
# 10     6
# 11    18
# Name: age, dtype: int64

# %%
df[['age','id']]
# Out:
#     age   id
# 0     6  NaN
# 1    18   13
# 2    18   14
# 3    19    ?
# 4    19   16
# 5     7   17
# 6    23   18
# 7    12   19
# 8    17  Nan
# 9    18   21
# 10    6  NaN
# 11   18   13

# %% [markdown]
# # Handle missing values

# %%
df.isna()
# Out:
#      Name     id    age
# 0   False   True  False
# 1   False  False  False
# 2   False  False  False
# 3   False  False  False
# 4   False  False  False
# 5   False  False  False
# 6   False  False  False
# 7   False  False  False
# 8   False  False  False
# 9   False  False  False
# 10  False   True  False
# 11  False  False  False

# %%
df.isna().sum()
# Out:
# Name    0
# id      2
# age     0
# dtype: int64

# %%
df.dropna(inplace=False)
# Out:
#        Name   id  age
# 1     divya   13   18
# 2      tanu   14   18
# 3     madhu    ?   19
# 4       sai   16   19
# 5     kanna   17    7
# 6   kishore   18   23
# 7       sri   19   12
# 8      ammu  Nan   17
# 9      ammu   21   18
# 11    divya   13   18

# %%
df.fillna(value=9)
# Out:
#        Name   id  age
# 0      asdf    9    6
# 1     divya   13   18
# 2      tanu   14   18
# 3     madhu    ?   19
# 4       sai   16   19
# 5     kanna   17    7
# 6   kishore   18   23
# 7       sri   19   12
# 8      ammu  Nan   17
# 9      ammu   21   18
# 10     asdf    9    6
# 11    divya   13   18

# %% [markdown]
# # Replace

# %%
import numpy as np
df1=df.replace(to_replace=np.nan,value=1234)
df1
# Out:
#        Name    id  age
# 0      asdf  1234    6
# 1     divya    13   18
# 2      tanu    14   18
# 3     madhu     ?   19
# 4       sai    16   19
# 5     kanna    17    7
# 6   kishore    18   23
# 7       sri    19   12
# 8      ammu   Nan   17
# 9      ammu    21   18
# 10     asdf  1234    6
# 11    divya    13   18

# %% [markdown]
# # Handle duplicated values

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#      Name   id  age
# 10   asdf  NaN    6
# 11  divya   13   18

# %%
df.drop_duplicates(inplace=False)
# Out:
#       Name   id  age
# 0     asdf  NaN    6
# 1    divya   13   18
# 2     tanu   14   18
# 3    madhu    ?   19
# 4      sai   16   19
# 5    kanna   17    7
# 6  kishore   18   23
# 7      sri   19   12
# 8     ammu  Nan   17
# 9     ammu   21   18

# %%
d=df.pop('age')
d
# Out:
# 0      6
# 1     18
# 2     18
# 3     19
# 4     19
# 5      7
# 6     23
# 7     12
# 8     17
# 9     18
# 10     6
# 11    18
# Name: age, dtype: int64
